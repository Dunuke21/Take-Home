# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
% matplotlib inline

# %%
df=pd.read_csv('http://vincentarelbundock.github.io/Rdatasets/csv/ggplot2/movies.csv')

# %%
from collections import Counter
Counter(df.Action)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-59b56b4f6ad0> in <module>()
#       1 from collections import Counter
# ----> 2 Counter(df.Action)
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
from collections import Counter
Counter(df_imdb.Action)
# Out:
# Counter({0: 54100, 1: 4688})

# %%
from collections import Counter
Counter(df_imdb.Animation)
# Out:
# Counter({0: 55098, 1: 3690})

# %%
from collections import Counter
Counter(df_imdb.Comedy)
# Out:
# Counter({0: 41517, 1: 17271})

# %%
from collections import Counter
Counter(df_imdb.Drama)
# Out:
# Counter({0: 36977, 1: 21811})

# %%
from collections import Counter
Counter(df_imdb.Documentary)
# Out:
# Counter({0: 55316, 1: 3472})

# %%
from collections import Counter
Counter(df_imdb.Romance)
# Out:
# Counter({0: 54044, 1: 4744})

# %%
from collections import Counter
Counter(df_imdb.Short)
# Out:
# Counter({0: 49330, 1: 9458})

# %%
labels=['Action','Animation','Comedy','Drama','Documentary','Romance','Short']
sizes=[4688,3690,17271,21811,3472,4744,9458]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.pie(sizes,labels=labels,autopct='%1.1f%%',shadow=True,startangle=90)
plt.title("Movie Type")

# %%
budget_series=df_imdb.groupby(['year'])['budget'].mean()
budget_series.plot()

# %%
budget_series=df_imdb.groupby(['year'])['rating'].mean()
budget_series.plot()

# %%
budget_series=df_imdb.groupby(['year'])['votes'].mean()
budget_series.plot()

# %%
df_hist=pd.DataFrame(df,columns=['rating'])
df_hist.head()
# Out:
#    rating
# 0     6.4
# 1     6.0
# 2     8.2
# 3     8.2
# 4     3.4

# %%
df_hist.plot(kind='hist',normed=True)
plt.savefig('histogram')

# %%
import seaborn as sns
sns.boxplot(x="Action",y="rating",data=df)
plt.savefig('boxplot')
